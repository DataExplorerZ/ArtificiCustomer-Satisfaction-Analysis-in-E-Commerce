# %%
import pandas as pd

# Specify the encoding when reading the CSV file
df = pd.read_csv("/content/Customer_support_data.csv", encoding='latin1')

# %%
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#                               Unique id channel_name         category  \
# 0  7e9ae164-6a8b-4521-a2d4-58f7c9fff13f      Outcall  Product Queries
# 1  b07ec1b0-f376-43b6-86df-ec03da3b2e16      Outcall  Product Queries
# 2  200814dd-27c7-4149-ba2b-bd3af3092880      Inbound    Order Related
# 3  eb0d3e53-c1ca-42d3-8486-e42c8d622135      Inbound          Returns
# 4  ba903143-1e54-406c-b969-46c52f92e5df      Inbound     Cancellation
#
#                    Sub-category Customer Remarks  \
# 0                Life Insurance              NaN
# 1  Product Specific Information              NaN
# 2             Installation/demo              NaN
# ...

# %% [markdown]
# ## **Data Preprocessing**

# %%
import pandas as pd

# List of columns to be removed
columns_to_remove = ['Unique id', 'Order_id', 'order_date_time', 'Issue_reported at', 'Customer Remarks','issue_responded', 'Survey_response_Date', 'connected_handling_time']

# Remove the specified columns
df = df.drop(columns=columns_to_remove)

# %%
df
# Out:
#       channel_name         category                  Sub-category  \
# 0          Outcall  Product Queries                Life Insurance
# 1          Outcall  Product Queries  Product Specific Information
# 2          Inbound    Order Related             Installation/demo
# 3          Inbound          Returns        Reverse Pickup Enquiry
# 4          Inbound     Cancellation                    Not Needed
# ...            ...              ...                           ...
# 85902      Inbound   Refund Related                Refund Enquiry
# 85903      Inbound    Order Related        Seller Cancelled Order
# 85904      Inbound    Order Related          Order status enquiry
# 85905      Inbound         Feedback      UnProfessional Behaviour
# 85906      Inbound          Returns        Reverse Pickup Enquiry
#
#       Customer_City Product_category  Item_price           Agent_name  \
# 0               NaN              NaN         NaN     Richard Buchanan
# ...

# %%
# Check for null values in the entire DataFrame
null_values_total = df.isnull().sum().sum()
print("Total null values in the DataFrame:", null_values_total)

# Check for null values in each column
null_values_per_column = df.isnull().sum()
print("Null values per column:")
print(null_values_per_column)
# Out:
# Total null values in the DataFrame: 206240
# Null values per column:
# channel_name            0
# category                0
# Sub-category            0
# Customer_City       68828
# Product_category    68711
# Item_price          68701
# Agent_name              0
# Supervisor              0
# Manager                 0
# Tenure Bucket           0
# Agent Shift             0
# CSAT Score              0
# dtype: int64

# %%
# Drop rows with null values
df_cleaned = df.dropna()

# Check if null values are dropped successfully
null_values_after_drop = df_cleaned.isnull().sum().sum()
print("Total null values in the DataFrame after dropping:", null_values_after_drop)
df=df_cleaned
# Out:
# Total null values in the DataFrame after dropping: 0

# %%
df
# Out:
#       channel_name       category              Sub-category  Customer_City  \
# 11         Inbound  Order Related                   Delayed         NAGPUR
# 16         Inbound        Returns   Service Centres Related         RANCHI
# 19         Inbound  Order Related         Installation/demo         NAGPUR
# 24         Inbound        Returns    Reverse Pickup Enquiry          BETIA
# 25         Inbound  Order Related      Order status enquiry      NEW DELHI
# ...            ...            ...                       ...            ...
# 85878      Inbound       Feedback  UnProfessional Behaviour      Singrauli
# 85881      Inbound  Order Related      Order status enquiry           PUNE
# 85886      Inbound        Returns                     Wrong       GUWAHATI
# 85900      Inbound  Order Related                   Delayed   BHUPALAPALLI
# 85901      Inbound  Order Related      Order status enquiry  IBRAHIMPATNAM
#
#                   Product_category  Item_price         Agent_name  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming 'df' is your DataFrame with categorical columns
# Replace 'df' with the name of your DataFrame

# List of categorical columns to be label encoded
categorical_columns = ['channel_name', 'category', 'Sub-category', 'Customer_City', 'Product_category', 'Agent_name', 'Supervisor', 'Manager', 'Tenure Bucket', 'Agent Shift']

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Apply label encoding to each categorical column
for col in categorical_columns:
    if col in df.columns:  # Check if the column exists in the DataFrame
        df[col] = label_encoder.fit_transform(df[col])

# Now, categorical columns are label encoded in the DataFrame 'df'
# Out:
# <ipython-input-8-c1c3c2eb4471>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = label_encoder.fit_transform(df[col])
# <ipython-input-8-c1c3c2eb4471>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = label_encoder.fit_transform(df[col])
# <ipython-input-8-c1c3c2eb4471>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame
# If you don't have a DataFrame, replace this with your data loading code
# For example:
# df = pd.read_csv('your_data.csv')

# Compute the correlation matrix
corr_matrix = df.corr()

# Plotting
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
df.head()
# Out:
#     channel_name  category  Sub-category  Customer_City  Product_category  \
# 11             1         3             7           1153                 7
# 16             1         8            34           1396                 2
# 19             1         3            11           1153                 2
# 24             1         8            30            224                 2
# 25             1         3            18           1208                 8
#
#     Item_price  Agent_name  Supervisor  Manager  Tenure Bucket  Agent Shift  \
# 11       434.0        1195          16        0              3            4
# 16      1299.0          58          36        2              0            2
# 19     15990.0         307          33        0              1            1
# 24      1099.0         281          37        2              1            2
# 25     99999.0         937          26        1              4            2
#
#     CSAT Score
# 11           1
# 16           5
# ...

# %%
# Check unique values of 'CSAT Score' and their counts
csat_score_counts = df['CSAT Score'].value_counts()

# Print the unique values of 'CSAT Score' and their counts
print("Unique values of CSAT Score and their counts:")
print(csat_score_counts)
# Out:
# Unique values of CSAT Score and their counts:
# CSAT Score
# 5    10669
# 1     3336
# 4     2157
# 3      567
# 2      332
# Name: count, dtype: int64

# %%
df
# Out:
#        channel_name  category  Sub-category  Customer_City  Product_category  \
# 11                1         3             7           1153                 7
# 16                1         8            34           1396                 2
# 19                1         3            11           1153                 2
# 24                1         8            30            224                 2
# 25                1         3            18           1208                 8
# ...             ...       ...           ...            ...               ...
# 85878             1         1            38           1632                 1
# 85881             1         3            18           1345                 2
# 85886             1         8            42            616                 6
# 85900             1         3             7            262                 1
# 85901             1         3            18            685                 8
#
# ...

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Assuming df contains your dataset with the subset of columns you provided

# Selecting subset of columns
selected_columns = ['channel_name', 'category', 'Sub-category', 'Customer_City',
                    'Product_category', 'Item_price', 'Agent_name', 'Supervisor',
                    'Manager', 'Tenure Bucket', 'Agent Shift', 'CSAT Score']

# Creating DataFrame with selected columns
selected_df = df[selected_columns]

# Handle missing values if any
selected_df.fillna(0, inplace=True)  # Replace NaNs with zeros, you may choose a different strategy

# Reset the index of selected DataFrame
selected_df.reset_index(drop=True, inplace=True)

# Standardize the features by removing the mean and scaling to unit variance
scaler = StandardScaler()
scaled_data = scaler.fit_transform(selected_df.drop(columns=['CSAT Score']))  # Exclude the target variable

# Create a PCA object
pca = PCA(n_components=2)  # You can adjust the number of components as needed

# Fit PCA to the scaled data
pca.fit(scaled_data)

# Transform the data to its principal components
pca_data = pca.transform(scaled_data)

# Create a DataFrame for the principal components
pca_df = pd.DataFrame(data=pca_data, columns=['PC1', 'PC2'])  # Change column names as needed

# Concatenate the principal components DataFrame with the target variable
final_df = pd.concat([pca_df, selected_df['CSAT Score']], axis=1)

# Now final_df contains the reduced-dimensional representation of your selected DataFrame with CSAT Score

# %%
final_df.dropna(inplace=True)

# %%
final_df['CSAT Score'] = final_df['CSAT Score'].astype(int)

# %%
df=final_df

# %%
df
# Out:
#             PC1       PC2  CSAT Score
# 0      1.537310 -0.991786           1
# 1     -1.566080 -1.701419           5
# 2      1.361457 -1.765242           5
# 3     -1.421105 -1.419698           5
# 4      3.360680 -0.378159           1
# ...         ...       ...         ...
# 17056 -0.179723 -0.003396           5
# 17057  0.633876  2.582148           5
# 17058 -1.741060  0.238771           4
# 17059  1.133021 -0.562068           5
# 17060  1.450937  0.002916           5
#
# [17061 rows x 3 columns]

# %% [markdown]
# ## **Data Preparation**

# %%
X = df.drop(columns=['CSAT Score'])
y = df['CSAT Score']

# %%
X
# Out:
#             PC1       PC2
# 0      1.537310 -0.991786
# 1     -1.566080 -1.701419
# 2      1.361457 -1.765242
# 3     -1.421105 -1.419698
# 4      3.360680 -0.378159
# ...         ...       ...
# 17056 -0.179723 -0.003396
# 17057  0.633876  2.582148
# 17058 -1.741060  0.238771
# 17059  1.133021 -0.562068
# 17060  1.450937  0.002916
#
# [17061 rows x 2 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize MinMaxScaler
scaler = MinMaxScaler()

# Fit and transform the data
X_normalized = scaler.fit_transform(X)

# Convert the normalized array back to a DataFrame
X_normalized_df = pd.DataFrame(X_normalized, columns=X.columns)

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X_normalized_df, y, test_size=0.2, random_state=42)

# %% [markdown]
# ## **Applying ANN**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Assuming X_normalized_df and y are already defined
# Assuming y contains categorical CSAT scores (e.g., satisfied, neutral, dissatisfied)

# Encode categorical labels into numerical values
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split the data into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X_normalized_df, y_encoded, test_size=0.2, random_state=42)

# Define the function to create the Keras model
def create_model(optimizer='adam', activation='relu', neurons=64):
    model = Sequential([
        Dense(neurons, activation=activation, input_shape=(X_train.shape[1],)),
        Dense(neurons // 2, activation=activation),
        Dense(len(np.unique(y_encoded)), activation='softmax')
    ])
    model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# Train the model
model = create_model(optimizer='adam', activation='relu')
history = model.fit(X_train, y_train, epochs=40, batch_size=32, validation_data=(X_test, y_test), verbose=1)

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# Epoch 1/40
# 427/427 [==============================] - 4s 6ms/step - loss: 1.1199 - accuracy: 0.6246 - val_loss: 1.0716 - val_accuracy: 0.6217
# Epoch 2/40
# 427/427 [==============================] - 3s 7ms/step - loss: 1.0659 - accuracy: 0.6262 - val_loss: 1.0649 - val_accuracy: 0.6217
# Epoch 3/40
# 427/427 [==============================] - 4s 9ms/step - loss: 1.0614 - accuracy: 0.6262 - val_loss: 1.0758 - val_accuracy: 0.6217
# Epoch 4/40
# 427/427 [==============================] - 3s 6ms/step - loss: 1.0609 - accuracy: 0.6262 - val_loss: 1.0701 - val_accuracy: 0.6217
# Epoch 5/40
# 427/427 [==============================] - 2s 6ms/step - loss: 1.0610 - accuracy: 0.6262 - val_loss: 1.0642 - val_accuracy: 0.6217
# Epoch 6/40
# 427/427 [==============================] - 2s 5ms/step - loss: 1.0606 - accuracy: 0.6262 - val_loss: 1.0636 - val_accuracy: 0.6217
# Epoch 7/40
# ...

# %%
# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)

# Predict on the test set
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)


# Plot training history
plt.figure(figsize=(4, 4))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training Accuracy vs Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.figure(figsize=(4, 4))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training Loss vs Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
